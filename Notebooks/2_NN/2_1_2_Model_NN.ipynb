# %% [markdown]
# # Neural Network with own Embedding with undersampling

# %% [markdown]
# ### Travail effectué
# * NN avec 4 couches
# * Sans fine tuning
# * Avec train dataset undersampling
#
# ### Conclusion
# * Enorme Underfitting
# * Le modèle a des meilleurs résultats avec ce dataset que le dataset complet

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import classification_report
from Fonctions_utils import f1_m, matrix_confusion

# %%
df_train = pd.read_csv("../../data_models/df_train_undersampling.csv")
df_val = pd.read_csv("../../data_models/df_val.csv")
df_test = pd.read_csv("../../data_models/df_test.csv")

# %%
sentences_train = df_train["text_clean"].values.astype(str)
sentences_val = df_val["text_clean"].values.astype(str)
sentences_test = df_test["text_clean"].values.astype(str)

y_train = df_train["Insult"].values
y_val = df_val["Insult"].values
y_test = df_test["Insult"].values

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(sentences_train)

X_train = tokenizer.texts_to_sequences(sentences_train)
X_val = tokenizer.texts_to_sequences(sentences_val)
X_test = tokenizer.texts_to_sequences(sentences_test)

vocab_size = len(tokenizer.word_index) + 1

# %% [markdown]
# The indexing is ordered after the most common words in the text, which you can see by the word the having the index 1. It is important to note that the index 0 is reserved and is not assigned to any word. This zero index is used for padding, which I’ll introduce in a moment

# %% [markdown]
# One problem that we have is that each text sequence has in most cases different length of words. To counter this, you can use pad_sequence() which simply pads the sequence of words with zeros. By default, it prepends zeros but we want to append them. Typically it does not matter whether you prepend or append zeros.

# %%
maxlen = 200

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_val = pad_sequences(X_val, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.GlobalMaxPool1D())
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=[f1_m,'accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 200, 50)           358600
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 359,121
# Trainable params: 359,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_f1_m', mode='min', patience=10)

history = model.fit(X_train, y_train,
                    epochs=30,
                    verbose=1,
                    validation_data=(X_val, y_val),
                    batch_size=10,
                    callbacks=[es])
# Out:
# Train on 1492 samples, validate on 1184 samples
# Epoch 1/30
# 1492/1492 [==============================] - 2s 2ms/sample - loss: 0.6872 - f1_m: 0.1437 - accuracy: 0.5462 - val_loss: 0.6656 - val_f1_m: 0.5088 - val_accuracy: 0.7796
# Epoch 2/30
# 1492/1492 [==============================] - 1s 950us/sample - loss: 0.6378 - f1_m: 0.6887 - accuracy: 0.7540 - val_loss: 0.5720 - val_f1_m: 0.5715 - val_accuracy: 0.7745
# Epoch 3/30
# 1492/1492 [==============================] - 1s 971us/sample - loss: 0.5135 - f1_m: 0.7840 - accuracy: 0.8076 - val_loss: 0.4667 - val_f1_m: 0.6014 - val_accuracy: 0.8066
# Epoch 4/30
# 1492/1492 [==============================] - 1s 900us/sample - loss: 0.3650 - f1_m: 0.8617 - accuracy: 0.8780 - val_loss: 0.4366 - val_f1_m: 0.6091 - val_accuracy: 0.7965
# Epoch 5/30
# 1492/1492 [==============================] - 1s 984us/sample - loss: 0.2444 - f1_m: 0.9242 - accuracy: 0.9296 - val_loss: 0.3791 - val_f1_m: 0.6250 - val_accuracy: 0.8260
# Epoch 6/30
# 1492/1492 [==============================] - 2s 1ms/sample - loss: 0.1593 - f1_m: 0.9490 - accuracy: 0.9638 - val_loss: 0.3735 - val_f1_m: 0.6287 - val_accuracy: 0.8311
# Epoch 7/30
# 1492/1492 [==============================] - 1s 999us/sample - loss: 0.1044 - f1_m: 0.9721 - accuracy: 0.9799 - val_loss: 0.3820 - val_f1_m: 0.6276 - val_accuracy: 0.8269
# Epoch 8/30
# 1492/1492 [==============================] - 1s 930us/sample - loss: 0.0685 - f1_m: 0.9839 - accuracy: 0.9873 - val_loss: 0.3836 - val_f1_m: 0.6245 - val_accuracy: 0.8277
# Epoch 9/30
# 1492/1492 [==============================] - 1s 940us/sample - loss: 0.0452 - f1_m: 0.9928 - accuracy: 0.9933 - val_loss: 0.3985 - val_f1_m: 0.6144 - val_accuracy: 0.8243
# Epoch 10/30
# 1492/1492 [==============================] - 1s 899us/sample - loss: 0.0317 - f1_m: 0.9956 - accuracy: 0.9960 - val_loss: 0.3936 - val_f1_m: 0.6164 - val_accuracy: 0.8311
# Epoch 11/30
# 1492/1492 [==============================] - 1s 926us/sample - loss: 0.0227 - f1_m: 0.9896 - accuracy: 0.9973 - val_loss: 0.4146 - val_f1_m: 0.6128 - val_accuracy: 0.8243

# %% [markdown]
# ## Performance

# %%
def plot_score_model(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    f1_m = history.history['f1_m']
    val_f1_m = history.history['val_f1_m']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 3, 1)
    plt.plot(x, f1_m, 'b', label='Training f1 Score')
    plt.plot(x, val_f1_m, 'r', label='Validation f1 Score')
    plt.title('F1 score')
    plt.legend()
    
    plt.subplot(1, 3, 2)    
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Accuracy')
    plt.legend()
    
    plt.subplot(1, 3, 3)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Loss')
    plt.legend()

# %%
plot_score_model(history)

# %%
y_predict_test = model.predict(X_test)
y_predict_test2 = [round(item) for sublist in y_predict_test.tolist() for item in sublist]

# %%
matrix_confusion(y_test, y_predict_test2)

# %%
target_names = ['Neutre', 'Insultant']
print(classification_report(y_test, y_predict_test2, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Neutre       0.90      0.87      0.88      1954
#    Insultant       0.65      0.71      0.68       693
#
#     accuracy                           0.83      2647
#    macro avg       0.78      0.79      0.78      2647
# weighted avg       0.83      0.83      0.83      2647
