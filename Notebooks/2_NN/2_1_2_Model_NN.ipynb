# %% [markdown]
# # Neural Network with own Embedding with undersampling

# %% [markdown]
# ### Travail effectué
# * NN avec 4 couches
# * Sans fine tuning
# * Avec train dataset undersampling
#
# ### Conclusion
# * Enorme Underfitting
# * Le modèle a des meilleurs résultats avec ce dataset que le dataset complet

# %%
import pandas as pd

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import classification_report
from Fonctions_utils import f1_m, matrix_confusion, plot_score_model

# %%
df_train = pd.read_csv("../../data_models/df_train_undersampling.csv")
df_val = pd.read_csv("../../data_models/df_val.csv")
df_test = pd.read_csv("../../data_models/df_test.csv")

# %%
sentences_train = df_train["text_clean"].values.astype(str)
sentences_val = df_val["text_clean"].values.astype(str)
sentences_test = df_test["text_clean"].values.astype(str)

y_train = df_train["Insult"].values
y_val = df_val["Insult"].values
y_test = df_test["Insult"].values

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(sentences_train)

X_train = tokenizer.texts_to_sequences(sentences_train)
X_val = tokenizer.texts_to_sequences(sentences_val)
X_test = tokenizer.texts_to_sequences(sentences_test)

vocab_size = len(tokenizer.word_index) + 1

# %% [markdown]
# The indexing is ordered after the most common words in the text, which you can see by the word the having the index 1. It is important to note that the index 0 is reserved and is not assigned to any word. This zero index is used for padding, which I’ll introduce in a moment

# %% [markdown]
# One problem that we have is that each text sequence has in most cases different length of words. To counter this, you can use pad_sequence() which simply pads the sequence of words with zeros. By default, it prepends zeros but we want to append them. Typically it does not matter whether you prepend or append zeros.

# %%
maxlen = 200

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_val = pad_sequences(X_val, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.GlobalMaxPool1D())
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=[f1_m,'accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 50)           358600
# _________________________________________________________________
# global_max_pooling1d (Global (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                510
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 359,121
# Trainable params: 359,121
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-21 11:14:57.880750: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 11:14:57.881206: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
es = EarlyStopping(monitor='val_f1_m', mode='min', patience=10)

history = model.fit(X_train, y_train,
                    epochs=30,
                    verbose=1,
                    validation_data=(X_val, y_val),
                    batch_size=10,
                    callbacks=[es])
# Out:
# Train on 1492 samples, validate on 1184 samples
# Epoch 1/30
# 1492/1492 [==============================] - 3s 2ms/sample - loss: 0.6866 - f1_m: 0.6615 - accuracy: 0.5295 - val_loss: 0.6933 - val_f1_m: 0.4771 - val_accuracy: 0.5127
# Epoch 2/30
# 1492/1492 [==============================] - 1s 931us/sample - loss: 0.6370 - f1_m: 0.7409 - accuracy: 0.6930 - val_loss: 0.6932 - val_f1_m: 0.4900 - val_accuracy: 0.5422
# Epoch 3/30
# 1492/1492 [==============================] - 1s 893us/sample - loss: 0.5248 - f1_m: 0.8201 - accuracy: 0.8063 - val_loss: 0.5879 - val_f1_m: 0.5752 - val_accuracy: 0.7128
# Epoch 4/30
# 1492/1492 [==============================] - 1s 893us/sample - loss: 0.3558 - f1_m: 0.8932 - accuracy: 0.9021 - val_loss: 0.4362 - val_f1_m: 0.6198 - val_accuracy: 0.8243
# Epoch 5/30
# 1492/1492 [==============================] - 1s 899us/sample - loss: 0.2223 - f1_m: 0.9510 - accuracy: 0.9511 - val_loss: 0.4366 - val_f1_m: 0.6407 - val_accuracy: 0.8159
# Epoch 6/30
# 1492/1492 [==============================] - 1s 894us/sample - loss: 0.1328 - f1_m: 0.9661 - accuracy: 0.9745 - val_loss: 0.5023 - val_f1_m: 0.6154 - val_accuracy: 0.7779
# Epoch 7/30
# 1492/1492 [==============================] - 1s 945us/sample - loss: 0.0824 - f1_m: 0.9778 - accuracy: 0.9832 - val_loss: 0.4256 - val_f1_m: 0.6277 - val_accuracy: 0.8176
# Epoch 8/30
# 1492/1492 [==============================] - 1s 899us/sample - loss: 0.0503 - f1_m: 0.9869 - accuracy: 0.9940 - val_loss: 0.4342 - val_f1_m: 0.6177 - val_accuracy: 0.8159
# Epoch 9/30
# 1492/1492 [==============================] - 1s 895us/sample - loss: 0.0332 - f1_m: 0.9968 - accuracy: 0.9966 - val_loss: 0.4585 - val_f1_m: 0.6222 - val_accuracy: 0.8150
# Epoch 10/30
# 1492/1492 [==============================] - 1s 915us/sample - loss: 0.0226 - f1_m: 0.9975 - accuracy: 0.9980 - val_loss: 0.4703 - val_f1_m: 0.6251 - val_accuracy: 0.8184
# Epoch 11/30
# 1492/1492 [==============================] - 1s 936us/sample - loss: 0.0169 - f1_m: 0.9890 - accuracy: 0.9966 - val_loss: 0.4849 - val_f1_m: 0.6233 - val_accuracy: 0.8184

# %% [markdown]
# ## Performance

# %%
plot_score_model(history)

# %%
y_predict_test = model.predict(X_test)
y_predict_test2 = [round(item) for sublist in y_predict_test.tolist() for item in sublist]

# %%
matrix_confusion(y_test, y_predict_test2)

# %%
target_names = ['Neutre', 'Insultant']
print(classification_report(y_test, y_predict_test2, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Neutre       0.90      0.83      0.86      1954
#    Insultant       0.60      0.73      0.66       693
#
#     accuracy                           0.80      2647
#    macro avg       0.75      0.78      0.76      2647
# weighted avg       0.82      0.80      0.81      2647
