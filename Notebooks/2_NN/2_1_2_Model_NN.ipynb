# %% [markdown]
# # Neural Network with own Embedding with undersampling

# %% [markdown]
# ### Travail effectué
# * NN avec 4 couches
# * Sans fine tuning
# * Avec train dataset undersampling
#
# ### Conclusion
# * Enorme Underfitting
# * Le modèle a des meilleurs résultats avec ce dataset que le dataset complet

# %%
import pandas as pd
from matplotlib import pyplot as plt

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

from sklearn.metrics import classification_report
from Fonctions_utils import f1_m, matrix_confusion

# %%
df_train = pd.read_csv("../../data_models/df_train_undersampling.csv")
df_val = pd.read_csv("../../data_models/df_val.csv")
df_test = pd.read_csv("../../data_models/df_test.csv")

# %%
sentences_train = df_train["text_clean"].values.astype(str)
sentences_val = df_val["text_clean"].values.astype(str)
sentences_test = df_test["text_clean"].values.astype(str)

y_train = df_train["Insult"].values
y_val = df_val["Insult"].values
y_test = df_test["Insult"].values

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(sentences_train)

X_train = tokenizer.texts_to_sequences(sentences_train)
X_val = tokenizer.texts_to_sequences(sentences_val)
X_test = tokenizer.texts_to_sequences(sentences_test)

vocab_size = len(tokenizer.word_index) + 1

# %% [markdown]
# The indexing is ordered after the most common words in the text, which you can see by the word the having the index 1. It is important to note that the index 0 is reserved and is not assigned to any word. This zero index is used for padding, which I’ll introduce in a moment

# %% [markdown]
# One problem that we have is that each text sequence has in most cases different length of words. To counter this, you can use pad_sequence() which simply pads the sequence of words with zeros. By default, it prepends zeros but we want to append them. Typically it does not matter whether you prepend or append zeros.

# %%
maxlen = 200

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_val = pad_sequences(X_val, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %%
embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.GlobalMaxPool1D())
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=[f1_m,'accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 50)           316300
# _________________________________________________________________
# global_max_pooling1d (Global (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                510
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 316,821
# Trainable params: 316,821
# Non-trainable params: 0
# _________________________________________________________________
# 2023-06-06 17:26:49.156782: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-06 17:26:49.157105: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
history = model.fit(X_train, y_train,
                    epochs=30,
                    verbose=1,
                    validation_data=(X_val, y_val),
                    batch_size=10)
# Out:
# Train on 1464 samples, validate on 1185 samples
# Epoch 1/30
# 1464/1464 [==============================] - 2s 2ms/sample - loss: 0.6832 - f1_m: 0.5087 - accuracy: 0.6038 - val_loss: 0.6585 - val_f1_m: 0.5430 - val_accuracy: 0.7013
# Epoch 2/30
# 1464/1464 [==============================] - 1s 864us/sample - loss: 0.5881 - f1_m: 0.7766 - accuracy: 0.7773 - val_loss: 0.5750 - val_f1_m: 0.5722 - val_accuracy: 0.7004
# Epoch 3/30
# 1464/1464 [==============================] - 1s 851us/sample - loss: 0.4261 - f1_m: 0.8283 - accuracy: 0.8443 - val_loss: 0.4734 - val_f1_m: 0.6233 - val_accuracy: 0.7840
# Epoch 4/30
# 1464/1464 [==============================] - 1s 869us/sample - loss: 0.2882 - f1_m: 0.9107 - accuracy: 0.9208 - val_loss: 0.4251 - val_f1_m: 0.6309 - val_accuracy: 0.8093
# Epoch 5/30
# 1464/1464 [==============================] - 1s 896us/sample - loss: 0.1895 - f1_m: 0.9391 - accuracy: 0.9474 - val_loss: 0.4485 - val_f1_m: 0.6432 - val_accuracy: 0.7983
# Epoch 6/30
# 1464/1464 [==============================] - 1s 884us/sample - loss: 0.1181 - f1_m: 0.9678 - accuracy: 0.9713 - val_loss: 0.4298 - val_f1_m: 0.6480 - val_accuracy: 0.8169
# Epoch 7/30
# 1464/1464 [==============================] - 1s 885us/sample - loss: 0.0734 - f1_m: 0.9858 - accuracy: 0.9857 - val_loss: 0.4411 - val_f1_m: 0.6505 - val_accuracy: 0.8169
# Epoch 8/30
# 1464/1464 [==============================] - 1s 842us/sample - loss: 0.0471 - f1_m: 0.9925 - accuracy: 0.9952 - val_loss: 0.4675 - val_f1_m: 0.6455 - val_accuracy: 0.8068
# Epoch 9/30
# 1464/1464 [==============================] - 1s 849us/sample - loss: 0.0305 - f1_m: 0.9971 - accuracy: 0.9973 - val_loss: 0.4887 - val_f1_m: 0.6388 - val_accuracy: 0.8025
# Epoch 10/30
# 1464/1464 [==============================] - 1s 877us/sample - loss: 0.0226 - f1_m: 0.9838 - accuracy: 0.9980 - val_loss: 0.4909 - val_f1_m: 0.6420 - val_accuracy: 0.8068
# Epoch 11/30
# 1464/1464 [==============================] - 1s 936us/sample - loss: 0.0158 - f1_m: 0.9988 - accuracy: 0.9986 - val_loss: 0.5061 - val_f1_m: 0.6414 - val_accuracy: 0.8042
# Epoch 12/30
# 1464/1464 [==============================] - 1s 871us/sample - loss: 0.0125 - f1_m: 0.9983 - accuracy: 0.9980 - val_loss: 0.5301 - val_f1_m: 0.6404 - val_accuracy: 0.8008
# Epoch 13/30
# 1464/1464 [==============================] - 1s 846us/sample - loss: 0.0102 - f1_m: 0.9980 - accuracy: 0.9980 - val_loss: 0.5291 - val_f1_m: 0.6453 - val_accuracy: 0.8076
# Epoch 14/30
# 1464/1464 [==============================] - 1s 844us/sample - loss: 0.0088 - f1_m: 0.9971 - accuracy: 0.9973 - val_loss: 0.5494 - val_f1_m: 0.6410 - val_accuracy: 0.8017
# Epoch 15/30
# 1464/1464 [==============================] - 1s 914us/sample - loss: 0.0077 - f1_m: 0.9986 - accuracy: 0.9986 - val_loss: 0.5538 - val_f1_m: 0.6424 - val_accuracy: 0.8042
# Epoch 16/30
# 1464/1464 [==============================] - 1s 869us/sample - loss: 0.0069 - f1_m: 0.9972 - accuracy: 0.9973 - val_loss: 0.5691 - val_f1_m: 0.6422 - val_accuracy: 0.8025
# Epoch 17/30
# 1464/1464 [==============================] - 1s 935us/sample - loss: 0.0062 - f1_m: 0.9985 - accuracy: 0.9980 - val_loss: 0.5743 - val_f1_m: 0.6461 - val_accuracy: 0.8059
# Epoch 18/30
# 1464/1464 [==============================] - 1s 845us/sample - loss: 0.0061 - f1_m: 0.9983 - accuracy: 0.9980 - val_loss: 0.5863 - val_f1_m: 0.6411 - val_accuracy: 0.8017
# Epoch 19/30
# 1464/1464 [==============================] - 1s 854us/sample - loss: 0.0052 - f1_m: 0.9899 - accuracy: 0.9980 - val_loss: 0.6030 - val_f1_m: 0.6408 - val_accuracy: 0.8000
# Epoch 20/30
# 1464/1464 [==============================] - 1s 853us/sample - loss: 0.0048 - f1_m: 0.9918 - accuracy: 0.9986 - val_loss: 0.5900 - val_f1_m: 0.6329 - val_accuracy: 0.8068
# Epoch 21/30
# 1464/1464 [==============================] - 1s 832us/sample - loss: 0.0039 - f1_m: 0.9918 - accuracy: 0.9986 - val_loss: 0.6152 - val_f1_m: 0.6406 - val_accuracy: 0.8000
# Epoch 22/30
# 1464/1464 [==============================] - 1s 910us/sample - loss: 0.0043 - f1_m: 0.9990 - accuracy: 0.9986 - val_loss: 0.6113 - val_f1_m: 0.6330 - val_accuracy: 0.8000
# Epoch 23/30
# 1464/1464 [==============================] - 1s 891us/sample - loss: 0.0046 - f1_m: 0.9983 - accuracy: 0.9986 - val_loss: 0.6205 - val_f1_m: 0.6345 - val_accuracy: 0.8017
# Epoch 24/30
# 1464/1464 [==============================] - 1s 898us/sample - loss: 0.0041 - f1_m: 0.9980 - accuracy: 0.9980 - val_loss: 0.6274 - val_f1_m: 0.6345 - val_accuracy: 0.8017
# Epoch 25/30
# 1464/1464 [==============================] - 1s 926us/sample - loss: 0.0035 - f1_m: 0.9988 - accuracy: 0.9986 - val_loss: 0.6234 - val_f1_m: 0.6396 - val_accuracy: 0.8084
# Epoch 26/30
# 1464/1464 [==============================] - 1s 956us/sample - loss: 0.0049 - f1_m: 0.9907 - accuracy: 0.9980 - val_loss: 0.6454 - val_f1_m: 0.6359 - val_accuracy: 0.8025
# Epoch 27/30
# 1464/1464 [==============================] - 1s 951us/sample - loss: 0.0039 - f1_m: 0.9979 - accuracy: 0.9980 - val_loss: 0.6511 - val_f1_m: 0.6373 - val_accuracy: 0.8034
# Epoch 28/30
# 1464/1464 [==============================] - 1s 879us/sample - loss: 0.0046 - f1_m: 0.9973 - accuracy: 0.9973 - val_loss: 0.6545 - val_f1_m: 0.6365 - val_accuracy: 0.8025
# Epoch 29/30
# 1464/1464 [==============================] - 1s 936us/sample - loss: 0.0033 - f1_m: 0.9989 - accuracy: 0.9986 - val_loss: 0.6537 - val_f1_m: 0.6409 - val_accuracy: 0.8076
# Epoch 30/30
# 1464/1464 [==============================] - 1s 908us/sample - loss: 0.0035 - f1_m: 0.9985 - accuracy: 0.9980 - val_loss: 0.6647 - val_f1_m: 0.6359 - val_accuracy: 0.8034

# %% [markdown]
# ## Performance

# %%
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
plot_history(history)

# %%
y_predict_test = model.predict(X_test)
y_predict_test2 = [round(item) for sublist in y_predict_test.tolist() for item in sublist]

# %%
matrix_confusion(y_test, y_predict_test2)

# %%
target_names = ['Neutre', 'Insultant']
print(classification_report(y_test, y_predict_test2, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Neutre       0.90      0.81      0.85      1954
#    Insultant       0.58      0.74      0.65       693
#
#     accuracy                           0.79      2647
#    macro avg       0.74      0.78      0.75      2647
# weighted avg       0.81      0.79      0.80      2647
